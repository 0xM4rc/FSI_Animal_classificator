# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.utils import to_categorical
import matplotlib.pyplot as plt
import random
import numpy as np
import tensorflow as tf

# %%
# Establecer una semilla para reproducibilidad
seed_value = 42
random.seed(seed_value)        # Semilla para Python
np.random.seed(seed_value)     # Semilla para NumPy
tf.random.set_seed(seed_value) # Semilla para TensorFlow/Keras

# A partir de aquí, puedes continuar con la construcción y entrenamiento de tu modelo de Keras

# %%
def generatePlot(history):
    # Extracción de datos
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    epochs = range(1, len(acc) + 1)

    # Creación del gráfico de accuracy
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, acc, 'b', label='Training')
    plt.plot(epochs, val_acc, 'r', label='Validation')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Creación del gráfico de loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs, loss, 'b', label='Training')
    plt.plot(epochs, val_loss, 'r', label='Validation')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Data Load

# %%
from keras.preprocessing.image import ImageDataGenerator
import os

image_size = 150
batch_size = 16
rescale_factor = 1./255

# Directorio conjunto entrenamiento
data_dir='Project_Animals/animals/Train/'
test_dir='Project_Animals/animals/Test'


# Crear un generador para aumentar datos
train_datagen = ImageDataGenerator(
    rescale=rescale_factor,    # Normalizar los valores de los píxeles
    shear_range=0.2,   # Rango para las transformaciones aleatorias
    zoom_range=0.2,    # Rango para el zoom aleatorio
    horizontal_flip=True, # Activar el giro horizontal aleatorio
    validation_split=0.2) # Establecer el porcentaje de imágenes para el conjunto de validación

# Cargar imágenes de entrenamiento
train_generator = train_datagen.flow_from_directory(
    data_dir,      # Directorio con datos
    target_size=(image_size, image_size), # Cambiar el tamaño de las imágenes a 50x50
    batch_size=batch_size,
    class_mode='categorical', # 'binary' para clasificación binaria, 'categorical' para multiclase
    subset='training') # Seleccionar solo el conjunto de entrenamiento

# Cargar imágenes de validación
validation_generator = train_datagen.flow_from_directory(
    data_dir,
    target_size=(image_size, image_size),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation') # Seleccionar solo el conjunto de validación

# Cargar imágenes de entrenamiento
test_generator = train_datagen.flow_from_directory(
    test_dir,
    target_size=(image_size, image_size),
    batch_size=16,
    class_mode='categorical'
)
# Out:
# Found 6462 images belonging to 6 classes.
# Found 1614 images belonging to 6 classes.
# Found 708 images belonging to 6 classes.

# %% [markdown]
# ## Model

# %%
model = Sequential()
# Capas convolucionales

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(image_size, image_size, 3)))
model.add(Dropout(0.2))  # Dropout después de la capa de conv2D
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(image_size, image_size, 3)))
model.add(Dropout(0.2))  # Dropout después de la capa de conv2D
model.add(MaxPooling2D(pool_size=(2, 2)))


# Agregar más capas convolucionales si es necesario

model.add(Flatten())# Aplanar la salida de la capa convolucional
# Aplanar la salida de la capa convolucional
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(6, activation='softmax'))  # Usar 'softmax' para clasificación multi-clase

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 148, 148, 32)      896
#
#  dropout_3 (Dropout)         (None, 148, 148, 32)      0
#
#  max_pooling2d_2 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 72, 72, 32)        9248
#
#  dropout_4 (Dropout)         (None, 72, 72, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 41472)             0
#
#  dense_2 (Dense)             (None, 64)                2654272
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 2,664,806
# Trainable params: 2,664,806
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ## Train

# %%
from keras.callbacks import EarlyStopping

# Configurar Early Stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)  # 'patience' es el número de épocas sin mejora después de las cuales el entrenamiento se detendrá

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
epochs = 100

# Entrenar el modelo con Early Stopping
history_of_train = model.fit_generator(
        train_generator,
        epochs=epochs,
        validation_data = validation_generator,
        callbacks = [early_stopping]
        ,steps_per_epoch=200
)
# Out:
# Epoch 1/100
# /tmp/ipykernel_18743/2278667360.py:5: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history_of_train = model.fit_generator(
# 2024-01-03 00:41:41.958301: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential_1/dropout_3/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 200/200 [==============================] - 20s 93ms/step - loss: 1.6748 - accuracy: 0.3122 - val_loss: 1.6186 - val_accuracy: 0.3482
# Epoch 2/100
# 200/200 [==============================] - 19s 93ms/step - loss: 1.4611 - accuracy: 0.4325 - val_loss: 1.4221 - val_accuracy: 0.4628
# Epoch 3/100
# 200/200 [==============================] - 19s 93ms/step - loss: 1.3681 - accuracy: 0.4734 - val_loss: 1.2650 - val_accuracy: 0.5508
# Epoch 4/100
# 200/200 [==============================] - 18s 92ms/step - loss: 1.3069 - accuracy: 0.5094 - val_loss: 1.2708 - val_accuracy: 0.5582
# Epoch 5/100
# 200/200 [==============================] - 19s 93ms/step - loss: 1.2549 - accuracy: 0.5266 - val_loss: 1.1651 - val_accuracy: 0.5762
# Epoch 6/100
# 200/200 [==============================] - 18s 92ms/step - loss: 1.2260 - accuracy: 0.5484 - val_loss: 1.1652 - val_accuracy: 0.5867
# Epoch 7/100
# 200/200 [==============================] - 19s 93ms/step - loss: 1.1763 - accuracy: 0.5622 - val_loss: 1.1926 - val_accuracy: 0.5669
# Epoch 8/100
# 200/200 [==============================] - 19s 95ms/step - loss: 1.1392 - accuracy: 0.5759 - val_loss: 1.1108 - val_accuracy: 0.6029
# Epoch 9/100
# 200/200 [==============================] - 19s 94ms/step - loss: 1.1089 - accuracy: 0.5854 - val_loss: 1.1253 - val_accuracy: 0.6097
# Epoch 10/100
# 200/200 [==============================] - 19s 94ms/step - loss: 1.1016 - accuracy: 0.5879 - val_loss: 1.0703 - val_accuracy: 0.6078
# Epoch 11/100
# 200/200 [==============================] - 18s 89ms/step - loss: 1.0717 - accuracy: 0.5941 - val_loss: 1.0816 - val_accuracy: 0.6183
# Epoch 12/100
# 200/200 [==============================] - 18s 89ms/step - loss: 1.1066 - accuracy: 0.5866 - val_loss: 1.0716 - val_accuracy: 0.6208
# Epoch 13/100
# 200/200 [==============================] - 19s 93ms/step - loss: 1.0854 - accuracy: 0.5825 - val_loss: 1.0322 - val_accuracy: 0.6475
# Epoch 14/100
# 200/200 [==============================] - 19s 96ms/step - loss: 0.9986 - accuracy: 0.6295 - val_loss: 0.9912 - val_accuracy: 0.6549
# Epoch 15/100
# 200/200 [==============================] - 18s 89ms/step - loss: 1.0013 - accuracy: 0.6320 - val_loss: 1.0125 - val_accuracy: 0.6351
# Epoch 16/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.9858 - accuracy: 0.6395 - val_loss: 1.0039 - val_accuracy: 0.6506
# Epoch 17/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.9801 - accuracy: 0.6345 - val_loss: 0.9834 - val_accuracy: 0.6512
# Epoch 18/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.9579 - accuracy: 0.6488 - val_loss: 0.9592 - val_accuracy: 0.6437
# Epoch 19/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.9340 - accuracy: 0.6562 - val_loss: 0.9382 - val_accuracy: 0.6797
# Epoch 20/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.9377 - accuracy: 0.6491 - val_loss: 0.9735 - val_accuracy: 0.6468
# Epoch 21/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.9347 - accuracy: 0.6450 - val_loss: 0.9793 - val_accuracy: 0.6462
# Epoch 22/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.8828 - accuracy: 0.6679 - val_loss: 0.9229 - val_accuracy: 0.6667
# Epoch 23/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.8918 - accuracy: 0.6687 - val_loss: 0.9118 - val_accuracy: 0.6679
# Epoch 24/100
# 200/200 [==============================] - 19s 97ms/step - loss: 0.8752 - accuracy: 0.6766 - val_loss: 0.9068 - val_accuracy: 0.6691
# Epoch 25/100
# 200/200 [==============================] - 19s 96ms/step - loss: 0.8678 - accuracy: 0.6757 - val_loss: 0.9407 - val_accuracy: 0.6499
# Epoch 26/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.8651 - accuracy: 0.6800 - val_loss: 0.9414 - val_accuracy: 0.6549
# Epoch 27/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.8369 - accuracy: 0.6859 - val_loss: 0.8981 - val_accuracy: 0.6636
# Epoch 28/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.8515 - accuracy: 0.6850 - val_loss: 0.8802 - val_accuracy: 0.6822
# Epoch 29/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.8071 - accuracy: 0.6953 - val_loss: 0.8937 - val_accuracy: 0.6698
# Epoch 30/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.8023 - accuracy: 0.7073 - val_loss: 0.9210 - val_accuracy: 0.6623
# Epoch 31/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.8281 - accuracy: 0.6928 - val_loss: 0.8861 - val_accuracy: 0.6877
# Epoch 32/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.7821 - accuracy: 0.7051 - val_loss: 0.8557 - val_accuracy: 0.6902
# Epoch 33/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.8020 - accuracy: 0.6995 - val_loss: 0.8903 - val_accuracy: 0.6729
# Epoch 34/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.7959 - accuracy: 0.7011 - val_loss: 0.9514 - val_accuracy: 0.6636
# Epoch 35/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.8057 - accuracy: 0.6881 - val_loss: 0.8793 - val_accuracy: 0.6778
# Epoch 36/100
# 200/200 [==============================] - 18s 88ms/step - loss: 0.7942 - accuracy: 0.6982 - val_loss: 0.8637 - val_accuracy: 0.6989
# Epoch 37/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.7740 - accuracy: 0.7092 - val_loss: 0.8585 - val_accuracy: 0.6964
# Epoch 38/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.7624 - accuracy: 0.7225 - val_loss: 0.8650 - val_accuracy: 0.6667
# Epoch 39/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.7520 - accuracy: 0.7220 - val_loss: 0.8423 - val_accuracy: 0.6958
# Epoch 40/100
# 200/200 [==============================] - 17s 87ms/step - loss: 0.7305 - accuracy: 0.7286 - val_loss: 0.8645 - val_accuracy: 0.6822
# Epoch 41/100
# 200/200 [==============================] - 18s 88ms/step - loss: 0.7221 - accuracy: 0.7427 - val_loss: 0.8522 - val_accuracy: 0.6908
# Epoch 42/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.7504 - accuracy: 0.7273 - val_loss: 0.9103 - val_accuracy: 0.6660
# Epoch 43/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.7385 - accuracy: 0.7203 - val_loss: 0.8784 - val_accuracy: 0.6753
# Epoch 44/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.7440 - accuracy: 0.7206 - val_loss: 0.8296 - val_accuracy: 0.7038
# Epoch 45/100
# 200/200 [==============================] - 18s 89ms/step - loss: 0.7167 - accuracy: 0.7326 - val_loss: 0.8769 - val_accuracy: 0.6735
# Epoch 46/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.7207 - accuracy: 0.7292 - val_loss: 0.8236 - val_accuracy: 0.7125
# Epoch 47/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.7173 - accuracy: 0.7298 - val_loss: 0.8121 - val_accuracy: 0.7007
# Epoch 48/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.7017 - accuracy: 0.7406 - val_loss: 0.8703 - val_accuracy: 0.6834
# Epoch 49/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.7084 - accuracy: 0.7341 - val_loss: 0.8899 - val_accuracy: 0.6846
# Epoch 50/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.6879 - accuracy: 0.7453 - val_loss: 0.8033 - val_accuracy: 0.7100
# Epoch 51/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.6829 - accuracy: 0.7416 - val_loss: 0.8492 - val_accuracy: 0.6964
# Epoch 52/100
# 200/200 [==============================] - 19s 93ms/step - loss: 0.6908 - accuracy: 0.7361 - val_loss: 0.8848 - val_accuracy: 0.6908
# Epoch 53/100
# 200/200 [==============================] - 18s 90ms/step - loss: 0.6815 - accuracy: 0.7492 - val_loss: 0.8620 - val_accuracy: 0.6896
# Epoch 54/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.6856 - accuracy: 0.7439 - val_loss: 0.8729 - val_accuracy: 0.6933
# Epoch 55/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.6738 - accuracy: 0.7472 - val_loss: 0.8356 - val_accuracy: 0.7007
# Epoch 56/100
# 200/200 [==============================] - 19s 95ms/step - loss: 0.6987 - accuracy: 0.7314 - val_loss: 0.8502 - val_accuracy: 0.7007
# Epoch 57/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.6658 - accuracy: 0.7441 - val_loss: 0.8241 - val_accuracy: 0.7113
# Epoch 58/100
# 200/200 [==============================] - 19s 94ms/step - loss: 0.6737 - accuracy: 0.7528 - val_loss: 0.8101 - val_accuracy: 0.6933
# Epoch 59/100
# 200/200 [==============================] - 18s 92ms/step - loss: 0.6828 - accuracy: 0.7459 - val_loss: 0.8101 - val_accuracy: 0.6896
# Epoch 60/100
# 200/200 [==============================] - 18s 91ms/step - loss: 0.6829 - accuracy: 0.7494 - val_loss: 0.8269 - val_accuracy: 0.6933

# %%
generatePlot(history_of_train)

# %% [markdown]
# ## Test

# %%
# Evaluar el modelo en el conjunto de validación (usado aquí como prueba)
# Puedes limitar el número de pasos para usar solo una parte del conjunto
test_loss, test_accuracy = model.evaluate(test_generator)  # 'steps' es el número de lotes a evaluar

print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# 45/45 [==============================] - 5s 115ms/step - loss: 0.9265 - accuracy: 0.6638
# Test Loss: 0.926513135433197
# Test Accuracy: 0.6638417840003967

# %%
# PRODUCTION ----------------------------------------------

#from matplotlib.pyplot import imshow
import numpy as np
#from PIL import Image
import tensorflow.keras

# SAVING --------------------------------------------------
model.save("mimodelo7.h5")


# LOADING --------------------------------------------------
model = tensorflow.keras.models.load_model("mimodelo7.h5")

etiquetas = ['Butterfly', 'Cat', 'Cow', 'Elephant', 'Sheep', 'Squirrel']
cantidad_pruebas = 5  # Número de pruebas que deseas realizar

print("ETIQUETA PREDICHA -> ETIQUETA REAL")
contador_pruebas = 0
for minilote in test_generator:
    if contador_pruebas >= cantidad_pruebas:
        break  # Salir del bucle después de realizar las 50 pruebas
        
    prediccion_minilote = model.predict(minilote[0])
    etiqueta_real_minilote = minilote[1]
    for y_predicha, y_real in zip(np.round(prediccion_minilote, 3), etiqueta_real_minilote):
        if np.argmax(y_predicha) == np.argmax(y_real):
            print(etiquetas[np.argmax(y_predicha)], "->", etiquetas[np.argmax(y_real)])
        else:
            print(etiquetas[np.argmax(y_predicha)], "->", etiquetas[np.argmax(y_real)], "✘")
    
    contador_pruebas += 1
# Out:
# ETIQUETA PREDICHA -> ETIQUETA REAL
# 1/1 [==============================] - 0s 91ms/step
# Elephant -> Elephant
# Sheep -> Sheep
# Sheep -> Cow ✘
# Squirrel -> Squirrel
# Squirrel -> Squirrel
# Cow -> Cow
# Elephant -> Elephant
# Sheep -> Elephant ✘
# Squirrel -> Squirrel
# Sheep -> Elephant ✘
# Sheep -> Sheep
# Butterfly -> Butterfly
# Sheep -> Sheep
# Cow -> Cow
# Squirrel -> Squirrel
# Squirrel -> Squirrel
# 1/1 [==============================] - 0s 18ms/step
# Butterfly -> Butterfly
# Squirrel -> Sheep ✘
# Squirrel -> Cat ✘
# Squirrel -> Squirrel
# Cat -> Cat
# Sheep -> Elephant ✘
# Sheep -> Sheep
# Elephant -> Sheep ✘
# Elephant -> Elephant
# Squirrel -> Squirrel
# Cat -> Cat
# Cow -> Cow
# Butterfly -> Butterfly
# Sheep -> Sheep
# Butterfly -> Butterfly
# Elephant -> Elephant
# 1/1 [==============================] - 0s 24ms/step
# Cow -> Cow
# Sheep -> Sheep
# Cat -> Cat
# Butterfly -> Butterfly
# Elephant -> Elephant
# Cow -> Cow
# Elephant -> Elephant
# Elephant -> Elephant
# Cat -> Cat
# Elephant -> Elephant
# Squirrel -> Squirrel
# Squirrel -> Elephant ✘
# Cat -> Squirrel ✘
# Elephant -> Elephant
# Squirrel -> Elephant ✘
# Cat -> Butterfly ✘
# 1/1 [==============================] - 0s 18ms/step
# Sheep -> Sheep
# Squirrel -> Cow ✘
# Elephant -> Elephant
# Squirrel -> Cat ✘
# Elephant -> Elephant
# Elephant -> Sheep ✘
# Cat -> Squirrel ✘
# Elephant -> Elephant
# Squirrel -> Cat ✘
# Elephant -> Elephant
# Cow -> Cow
# Elephant -> Elephant
# Sheep -> Cow ✘
# Cow -> Cow
# Cat -> Cat
# Sheep -> Cow ✘
# 1/1 [==============================] - 0s 19ms/step
# Cow -> Elephant ✘
# Sheep -> Cow ✘
# Squirrel -> Butterfly ✘
# Sheep -> Sheep
# Butterfly -> Cat ✘
# Squirrel -> Squirrel
# Squirrel -> Squirrel
# Cow -> Cow
# Squirrel -> Squirrel
# Elephant -> Elephant
# Sheep -> Sheep
# Sheep -> Cow ✘
# Elephant -> Elephant
# Cat -> Squirrel ✘
# Elephant -> Elephant
# Cat -> Squirrel ✘
